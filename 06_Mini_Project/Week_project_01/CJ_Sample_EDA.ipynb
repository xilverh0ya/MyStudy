# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:\DataSet\CJ_월 단위_물류배송_데이터\Sample_data\자치구단위\자치구단위 월별 착지 데이터.csv', encoding='cp949')
df
# Out:
#     기준년월(BASE_DY) 자치구(ADDR)  대분류_착지물동량_가구/인테리어(E_C_01)  대분류_착지물동량_기타(E_C_02)  \
# 0          202103       강남구                      25035                281991
# 1          202104       서초구                      19508                259466
# 2          202105      서대문구                      16904                384154
# 3          202102       강서구                      46705                216690
# 4          202102       성동구                      35119                240743
# 5          202102       성북구                      34412                248623
# 6          202106       강북구                      24601                274533
# 7          202104       구로구                      50966                280295
# 8          202104       마포구                      22408                158557
# 9          202106        중구                      21845                575340
# 10         202102       관악구                      27617                403293
# ...

# %%
df.shape
# Out:
# (25, 142)

# %%
df['자치구(ADDR)'].nunique()
# Out:
# 25

# %%
df2 = pd.read_csv('D:\DataSet\CJ_월 단위_물류배송_데이터\Sample_data\자치구단위\자치구단위 월별 착지 데이터.csv', encoding='cp949', index_col='자치구(ADDR)')
df2
# Out:
#            기준년월(BASE_DY)  대분류_착지물동량_가구/인테리어(E_C_01)  대분류_착지물동량_기타(E_C_02)  \
# 자치구(ADDR)
# 강남구               202103                      25035                281991
# 서초구               202104                      19508                259466
# 서대문구              202105                      16904                384154
# 강서구               202102                      46705                216690
# 성동구               202102                      35119                240743
# 성북구               202102                      34412                248623
# 강북구               202106                      24601                274533
# 구로구               202104                      50966                280295
# 마포구               202104                      22408                158557
# 중구                202106                      21845                575340
# 관악구               202102                      27617                403293
# ...

# %%
df['기준년월(BASE_DY)'].unique()
# Out:
# array([202103, 202104, 202105, 202102, 202106, 202101], dtype=int64)
